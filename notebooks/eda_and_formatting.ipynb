# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_test = pd.read_csv('../data/df_test.csv')

# %%
df_test.head()
# Out:
#                 title   tv  year rating  score_imdb score_rotten netflix Hulu  \
# 0        Breaking Bad   TV  2008    18+         9.5          96%     Yes  NaN
# 1           Inception  NaN  2010    13+         8.8          87%     Yes  NaN
# 2  Back to the Future  NaN  1985     7+         8.5          96%     Yes  NaN
# 3          The Matrix  NaN  1999    18+         8.7          88%     Yes  NaN
# 4     Stranger Things   TV  2016    16+         8.8          93%     Yes  NaN
#
#   Prime Video  Disney+  HBO Max  \
# 0         NaN      NaN      NaN
# 1         NaN      NaN      NaN
# 2         NaN      NaN      NaN
# 3         NaN      NaN      NaN
# 4         NaN      NaN      NaN
#
#                                                 link  \
# 0        https://reelgood.com/show/breaking-bad-2008
# 1          https://reelgood.com/movie/inception-2010
# 2  https://reelgood.com/movie/back-to-the-future-...
# 3         https://reelgood.com/movie/the-matrix-1999
# ...

# %%
df_test = pd.concat([Series(row['var2'], row['var1'].split(','))              
                    for i, row in a.iterrows()]).reset_index()
